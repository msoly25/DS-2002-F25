# %% [markdown]
# <a href="https://colab.research.google.com/github/msoly25/DS-2002-F25/blob/main/DS_3001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/msoly25/scratchpad
# %run ./scratchpad/get_data.py
# Out:
# Cloning into 'scratchpad'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 24 (delta 0), reused 0 (delta 0), pack-reused 22 (from 1)
# Receiving objects: 100% (24/24), 25.56 KiB | 6.39 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# ...
# Download complete
# Extracting data files...
# Data extracted

# %%
import pandas as pd
df = pd.read_csv('/content/data/mn_police_use_of_force.csv', encoding = 'utf_8')
df.head(2)
# Out:
#      response_datetime               problem is_911_call primary_offense  \
# 0  2016/01/01 00:47:36  Assault in Progress          Yes          DASLT1
# 1  2016/01/01 02:19:34                Fight           No          DISCON
#
#   subject_injury         force_type   force_type_action   race     sex   age  \
# 0            NaN       Bodily Force  Body Weight to Pin  Black    Male  20.0
# 1            NaN  Chemical Irritant       Personal Mace  Black  Female  27.0
#
#          type_resistance  precinct   neighborhood
# 0                 Tensed         1  Downtown East
# 1  Verbal Non-Compliance         1  Downtown West

# %%
df.shape
# Out:
# (12925, 13)

# %%
import pandas as pd

# %%
df['force_type'].describe()
# Out:
# count            12925
# unique              11
# top       Bodily Force
# freq              9430
# Name: force_type, dtype: object
